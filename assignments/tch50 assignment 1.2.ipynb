# %% [markdown]
# # Assignment Part 2: Plot from Simulated Data

# %% [markdown]
# Here, I took the sample file and modified a few variables to get an output that looked different from the original (changed color, changed n, changed weight of the dots).

# %%
# Import numeric libraries
import numpy as np
import pandas as pd

# Enable
# %pylab inline

# simulate random data
np.random.normal()

# Simulate data
n = 50
x = np.random.normal(size=n)
y = np.random.normal(size=n)

# Generate figure with matplotlib
fig, ax = plt.subplots(figsize=(8,8))

# Plot scatter of randomly distributed data
ax.scatter(x, y, c='blue', lw=2, alpha=.8)

# Annotate plot
ax.set_title('2D Normally Distributed Data')
ax.set_xlabel('X')
ax.set_ylabel('Y')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Text(0,0.5,'Y')
